# %% [markdown]
# <h1 style='color:green'>ABOUT</h1>
#
# <p style='color:lightgreen'>These last decades, Earth Observation brought quantities of new perspectives from geosciences to human activity monitoring. As more data became available, artificial intelligence techniques led to very successful results for understanding remote sensing data. Moreover, various acquisition techniques such as Synthetic Aperture Radar (SAR) can also be used for problems that could not be tackled only through optical images. This is the case for weather-related disasters such as floods or hurricanes, which are generally associated with large clouds cover. Yet, machine learning on SAR data is still considered challenging due to the lack of available labeled data. This dataset is composed of co-registered optical and SAR images time series for the detection of flood events.</p>
#
# [source](https://mlhub.earth/data/sen12floods)

# %% [markdown]
# <h2 style='color:green'>Dataset</h2>
#
# <p style='color:lightgreen'>The dataset is composed of 412
# time series with 4 to 20 optical images and 10 to 58 SAR im-
# ages in each sequence. On average, there are 9 optical and 14
# SAR images per sequence. The period of acquisition goes from
# December 2018 to May 2019. A flood event is occuring in 40%
# of the optical Sentinel 2 images and in 47% of the SAR Sen-
# tinel 1 images. As in the MediaEval dataset, once a flood oc-
# curred in a sequence, all the subsequent images are labeled as
# flooded which corresponds to the hypothesis that the surface
# still presents characteristic modifications after the event.</p>
#
# [source](https://www.int-arch-photogramm-remote-sens-spatial-inf-sci.net/XLIII-B2-2020/1343/2020/isprs-archives-XLIII-B2-2020-1343-2020.pdf)

# %% [markdown]
# <h2 style='color:green'>Other notebooks related to this project</h2>
#
#
# * [Data Download](https://www.kaggle.com/code/virajkadam/detecting-flood-from-satellite-img-data-download)
#
# * [The next notebook in this series(Time Series)](https://www.kaggle.com/virajkadam/detecting-floods-time-series-prediction)

# %% [markdown]
# # Imports

# %%
import json
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np 
import pandas as pd
import seaborn as sns
import os
import gc
import rasterio as rio
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib import  cm
import cv2
from matplotlib import animation
from IPython.display import HTML
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Config

# %%
class CFG:
    seed = 7
    img_size = (256,256)
    BATCH_SIZE = 3
    Autotune = tf.data.AUTOTUNE
    validation_size = 0.2
    class_dict= {0:'No Flooding', 
                 1: 'Flooding'}
    
    test_run = False

# %% [markdown]
# # Input data
#
#     Read more about the dataset here : https://clmrmb.github.io/SEN12-FLOOD/

# %%
# Chargement du fichier JSON
with open('SEN12FLOOD/S1list.json', 'r') as f:
    s1_metadata = json.load(f)

# Parcours des données
for area_id, area_data in s1_metadata.items():
    print(f"Zone : {area_id} , et le count est de {area_data['count']}")
    count = area_data['count']
    folder = area_data['folder']
    for i in range(1, count + 1):
        entry = area_data[str(i)]
        date = entry['date']
        flooding = entry['FLOODING']
        orbit = entry['orbit']
        filename = entry['filename']
        print(f"  Image {i}:")
        print(f"    Date : {date}")
        print(f"    Inondation : {flooding}")
        print(f"    Orbite : {orbit}")
        print(f"    Nom de fichier : {filename}")
# Out:
# Zone : 0063 , et le count est de 2
#   Image 1:
#     Date : 2019-01-28
#     Inondation : False
#     Orbite : ASCENDING
#     Nom de fichier : S1B_IW_GRDH_1SDV_20190128T163241_20190128T163306_014696_01B65E_5615
#   Image 2:
#     Date : 2019-02-09
#     Inondation : False
#     Orbite : ASCENDING
#     Nom de fichier : S1B_IW_GRDH_1SDV_20190209T163240_20190209T163305_014871_01BC1F_7E74
# Zone : 0200 , et le count est de 14
#   Image 1:
#     Date : 2019-02-23
#     Inondation : False
#     Orbite : DESCENDING
#     Nom de fichier : S1A_IW_GRDH_1SDV_20190223T031705_20190223T031730_026051_02E795_2CA5
#   Image 2:
#     Date : 2019-02-28
#     Inondation : False
#     Orbite : ASCENDING
#     Nom de fichier : S1B_IW_GRDH_1SDV_20
#     Inondation : False
#     Orbite : ASCENDING
#     Nom de fichier : S1A_IW_GRDH_1SDV_20190207T160454_20190207T160519_025825_02DF8C_59F6
#   Image 12:
#     Date : 2019-02-12
#     Inondation : False
#     Orbite : ASCENDING
#     Nom de fichier : S1A_IW_GRDH_1SDV_20190212T161246_20190212T161311_025898_02E225_8914

# %%
with open("SEN12FLOOD/S2list.json", 'r') as f:
    s2_metadata = json.load(f)

for area_id, area_data in s2_metadata.items():
    print(f"Zone : {area_id}")
    count = area_data.get('count', 0)
    folder = area_data.get('folder', '')
    print(f"  Nombre d'images : {count}")
    print(f"  Dossier : {folder}")
    for i in range(1, count + 1):
        entry = area_data.get(str(i), {})
        date = entry.get('date', '')
        flooding = entry.get('FLOODING', '')
        full_coverage = entry.get('FULL-DATA-COVERAGE', '')
        filename = entry.get('filename', '')
        print(f"    Image {i}:")
        print(f"      Date : {date}")
        print(f"      Inondation : {flooding}")
        print(f"      Couverture complète : {full_coverage}")
        print(f"      Nom de fichier : {filename}")
# Out:
# Zone : 0063
#   Nombre d'images : 1
#   Dossier : 0063
#     Image 1:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
# Zone : 0200
#   Nombre d'images : 8
#   Dossier : 0200
#     Image 1:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 2:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 3:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-10
#     Image 4:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 5:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 6:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-14
#     Image 7:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
#     Image 8:
#       Date : 2019-04-29
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-29
# Zone : 0004
#   Nombre d'images : 9
#   Dossier : 0004
#     Image 1:
#       Date : 2018-12-15
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2018-12-15
#     Image 2:
#       Date : 2018-12-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-17
#     Image 3:
#       Date : 2018-12-20
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2018-12-20
#     Image 4:
#       Date : 2018-12-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-22
#     Image 5:
#       Date : 2018-12-30
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2018-12-30
#     Image 6:
#       Date : 2019-01-04
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-04
#     Image 7:
#       Date : 2019-01-06
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-06
#     Image 8:
#       Date : 2019-01-14
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-14
#     Image 9:
#       Date : 2019-01-16
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-16
# Zone : 0307
#   Nombre d'images : 4
#   Dossier : 0307
#     Image 1:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 2:
#       Date : 2019-02-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 3:
#       Date : 2019-02-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-15
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-15
# Zone : 0167
#   Nombre d'images : 5
#   Dossier : 0167
#     Image 1:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 2:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 3:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 4:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-01
#     Image 5:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
# Zone : 0205
#   Nombre d'images : 9
#   Dossier : 0205
#     Image 1:
#       Date : 2019-02-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 2:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 3:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-10
#     Image 5:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 6:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 7:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-14
#     Image 8:
#       Date : 2019-04-19
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-19
#     Image 9:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
# Zone : 0166
#   Nombre d'images : 5
#   Dossier : 0166
#     Image 1:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 2:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 3:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 4:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-01
#     Image 5:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
# Zone : 0240
#   Nombre d'images : 9
#   Dossier : 0240
#     Image 1:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 2:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 3:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 4:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 5:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
#     Image 6:
#       Date : 2019-03-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-27
#     Image 7:
#       Date : 2019-04-08
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-08
#     Image 8:
#       Date : 2019-04-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
#     Image 9:
#       Date : 2019-04-23
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-23
# Zone : 0123
#   Nombre d'images : 6
#   Dossier : 0123
#     Image 1:
#       Date : 2018-12-15
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-15
#     Image 2:
#       Date : 2018-12-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-17
#     Image 3:
#       Date : 2018-12-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-27
#     Image 4:
#       Date : 2019-01-24
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-24
#     Image 5:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 6:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
# Zone : 61
#   Nombre d'images : 9
#   Dossier : 61
#     Image 1:
#       Date : 2019-02-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 2:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 3:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-10
#     Image 5:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 6:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 7:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-14
#     Image 8:
#       Date : 2019-04-19
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-19
#     Image 9:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
# Zone : 31
#   Nombre d'images : 7
#   Dossier : 31
#     Image 1:
#       Date : 2018-12-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-26
#     Image 2:
#       Date : 2018-12-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-31
#     Image 3:
#       Date : 2019-01-05
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-05
#     Image 4:
#       Date : 2019-01-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-10
#     Image 5:
#       Date : 2019-01-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-30
#     Image 6:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
#     Image 7:
#       Date : 2019-02-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-14
# Zone : 0310
#   Nombre d'images : 4
#   Dossier : 0310
#     Image 1:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 2:
#       Date : 2019-02-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 3:
#       Date : 2019-02-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-15
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-15
# Zone : 0122
#   Nombre d'images : 6
#   Dossier : 0122
#     Image 1:
#       Date : 2018-12-15
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-15
#     Image 2:
#       Date : 2018-12-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-17
#     Image 3:
#       Date : 2018-12-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-27
#     Image 4:
#       Date : 2019-01-24
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-24
#     Image 5:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 6:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
# Zone : 0182
#   Nombre d'images : 6
#   Dossier : 0182
#     Image 1:
#       Date : 2019-02-01
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-01
#     Image 2:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
#     Image 3:
#       Date : 2019-02-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-21
#     Image 4:
#       Date : 2019-03-03
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-03
#     Image 5:
#       Date : 2019-03-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-28
#     Image 6:
#       Date : 2019-04-27
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-27
# Zone : 0046
#   Nombre d'images : 3
#   Dossier : 0046
#     Image 1:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 2:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-02
#     Image 3:
#       Date : 2019-02-01
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-01
# Zone : 0280
#   Nombre d'images : 9
#   Dossier : 0280
#     Image 1:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 2:
#       Date : 2019-03-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-02
#     Image 3:
#       Date : 2019-03-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-04
#     Image 4:
#       Date : 2019-03-07
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-07
#     Image 5:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 6:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 7:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 8:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 9:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
# Zone : 0285
#   Nombre d'images : 9
#   Dossier : 0285
#     Image 1:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 2:
#       Date : 2019-03-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-02
#     Image 3:
#       Date : 2019-03-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-04
#     Image 4:
#       Date : 2019-03-07
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-07
#     Image 5:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 6:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 7:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 8:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 9:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
# Zone : 0145
#   Nombre d'images : 9
#   Dossier : 0145
#     Image 1:
#       Date : 2019-01-26
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-26
#     Image 2:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 3:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 4:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 5:
#       Date : 2019-03-12
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 6:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-01
#     Image 7:
#       Date : 2019-04-06
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-06
#     Image 8:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
#     Image 9:
#       Date : 2019-04-21
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-21
# Zone : 0026
#   Nombre d'images : 4
#   Dossier : 0026
#     Image 1:
#       Date : 2018-12-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-14
#     Image 2:
#       Date : 2019-01-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-13
#     Image 3:
#       Date : 2019-01-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-23
#     Image 4:
#       Date : 2019-01-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-28
# Zone : 0100
#   Nombre d'images : 7
#   Dossier : 0100
#     Image 1:
#       Date : 2018-12-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-13
#     Image 2:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 3:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-02
#     Image 4:
#       Date : 2019-01-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-22
#     Image 5:
#       Date : 2019-01-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-27
#     Image 6:
#       Date : 2019-02-06
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-06
#     Image 7:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
# Zone : 0231
#   Nombre d'images : 9
#   Dossier : 0231
#     Image 1:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 2:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 3:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 4:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 5:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
#     Image 6:
#       Date : 2019-03-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-27
#     Image 7:
#       Date : 2019-04-08
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-08
#     Image 8:
#       Date : 2019-04-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
#     Image 9:
#       Date : 2019-04-23
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-23
# Zone : 0043
#   Nombre d'images : 3
#   Dossier : 0043
#     Image 1:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 2:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-02
#     Image 3:
#       Date : 2019-02-01
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-01
# Zone : 0223
#   Nombre d'images : 9
#   Dossier : 0223
#     Image 1:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 2:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 3:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 4:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 5:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
#     Image 6:
#       Date : 2019-03-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-27
#     Image 7:
#       Date : 2019-04-08
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-08
#     Image 8:
#       Date : 2019-04-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
#     Image 9:
#       Date : 2019-04-23
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-23
# Zone : 0221
#   Nombre d'images : 9
#   Dossier : 0221
#     Image 1:
#       Date : 2019-02-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 2:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 3:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-10
#     Image 5:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 6:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 7:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-14
#     Image 8:
#       Date : 2019-04-19
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-19
#     Image 9:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
# Zone : 28
#   Nombre d'images : 7
#   Dossier : 28
#     Image 1:
#       Date : 2018-12-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-13
#     Image 2:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 3:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-02
#     Image 4:
#       Date : 2019-01-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-22
#     Image 5:
#       Date : 2019-01-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-27
#     Image 6:
#       Date : 2019-02-06
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-06
#     Image 7:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
# Zone : 39
#   Nombre d'images : 7
#   Dossier : 39
#     Image 1:
#       Date : 2018-12-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-26
#     Image 2:
#       Date : 2018-12-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-31
#     Image 3:
#       Date : 2019-01-05
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-05
#     Image 4:
#       Date : 2019-01-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-10
#     Image 5:
#       Date : 2019-01-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-30
#     Image 6:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
#     Image 7:
#       Date : 2019-02-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-14
# Zone : 0154
#   Nombre d'images : 9
#   Dossier : 0154
#     Image 1:
#       Date : 2019-01-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-26
#     Image 2:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 3:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 4:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 5:
#       Date : 2019-03-12
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 6:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-01
#     Image 7:
#       Date : 2019-04-06
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-06
#     Image 8:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
#     Image 9:
#       Date : 2019-04-21
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
# Zone : 0177
#   Nombre d'images : 7
#   Dossier : 0177
#     Image 1:
#       Date : 2019-02-01
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-01
#     Image 2:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
#     Image 3:
#       Date : 2019-02-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-21
#     Image 4:
#       Date : 2019-03-03
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-03
#     Image 5:
#       Date : 2019-03-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-28
#     Image 6:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-24
#     Image 7:
#       Date : 2019-04-27
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-27
# Zone : 0261
#   Nombre d'images : 9
#   Dossier : 0261
#     Image 1:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 2:
#       Date : 2019-03-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-02
#     Image 3:
#       Date : 2019-03-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-04
#     Image 4:
#       Date : 2019-03-07
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-07
#     Image 5:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 6:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 7:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-17
#     Image 8:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 9:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
# Zone : 0209
#   Nombre d'images : 9
#   Dossier : 0209
#     Image 1:
#       Date : 2019-02-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 2:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 3:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-10
#     Image 5:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 6:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 7:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-14
#     Image 8:
#       Date : 2019-04-19
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-19
#     Image 9:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
# Zone : 0023
#   Nombre d'images : 4
#   Dossier : 0023
#     Image 1:
#       Date : 2018-12-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-14
#     Image 2:
#       Date : 2019-01-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-13
#     Image 3:
#       Date : 2019-01-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-23
#     Image 4:
#       Date : 2019-01-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-28
# Zone : 0232
#   Nombre d'images : 9
#   Dossier : 0232
#     Image 1:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 2:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 3:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 4:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 5:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
#     Image 6:
#       Date : 2019-03-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-27
#     Image 7:
#       Date : 2019-04-08
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-08
#     Image 8:
#       Date : 2019-04-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
#     Image 9:
#       Date : 2019-04-23
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-23
# Zone : 0067
#   Nombre d'images : 1
#   Dossier : 0067
#     Image 1:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
# Zone : 0256
#   Nombre d'images : 9
#   Dossier : 0256
#     Image 1:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 2:
#       Date : 2019-03-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-02
#     Image 3:
#       Date : 2019-03-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-04
#     Image 4:
#       Date : 2019-03-07
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-07
#     Image 5:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 6:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 7:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-17
#     Image 8:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 9:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
# Zone : 65
#   Nombre d'images : 9
#   Dossier : 65
#     Image 1:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 2:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 3:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 4:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 5:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
#     Image 6:
#       Date : 2019-03-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-27
#     Image 7:
#       Date : 2019-04-08
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-08
#     Image 8:
#       Date : 2019-04-21
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
#     Image 9:
#       Date : 2019-04-23
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-23
# Zone : 0133
#   Nombre d'images : 9
#   Dossier : 0133
#     Image 1:
#       Date : 2018-12-16
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-16
#     Image 2:
#       Date : 2018-12-19
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2018-12-19
#     Image 3:
#       Date : 2018-12-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-26
#     Image 4:
#       Date : 2019-01-05
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-05
#     Image 5:
#       Date : 2019-01-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-10
#     Image 6:
#       Date : 2019-01-13
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-13
#     Image 7:
#       Date : 2019-01-15
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-15
#     Image 8:
#       Date : 2019-01-18
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-18
#     Image 9:
#       Date : 2019-01-23
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-23
# Zone : 0055
#   Nombre d'images : 3
#   Dossier : 0055
#     Image 1:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 2:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-01-02
#     Image 3:
#       Date : 2019-02-01
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-01
# Zone : 0169
#   Nombre d'images : 5
#   Dossier : 0169
#     Image 1:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 2:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 3:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 4:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-01
#     Image 5:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
# Zone : 0021
#   Nombre d'images : 9
#   Dossier : 0021
#     Image 1:
#       Date : 2018-12-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-25
#     Image 2:
#       Date : 2018-12-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-30
#     Image 3:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 4:
#       Date : 2019-01-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-14
#     Image 5:
#       Date : 2019-01-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-19
#     Image 6:
#       Date : 2019-01-24
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-24
#     Image 7:
#       Date : 2019-01-29
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-29
#     Image 8:
#       Date : 2019-02-03
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-03
#     Image 9:
#       Date : 2019-02-08
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-02-08
# Zone : 0222
#   Nombre d'images : 9
#   Dossier : 0222
#     Image 1:
#       Date : 2019-02-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 2:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 3:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-10
#     Image 5:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 6:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 7:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-14
#     Image 8:
#       Date : 2019-04-19
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-19
#     Image 9:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
# Zone : 0321
#   Nombre d'images : 4
#   Dossier : 0321
#     Image 1:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 2:
#       Date : 2019-02-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 3:
#       Date : 2019-02-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-15
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-15
# Zone : 0213
#   Nombre d'images : 9
#   Dossier : 0213
#     Image 1:
#       Date : 2019-02-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 2:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-23
#     Image 3:
#       Date : 2019-02-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-10
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-10
#     Image 5:
#       Date : 2019-03-25
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-25
#     Image 6:
#       Date : 2019-04-04
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-04
#     Image 7:
#       Date : 2019-04-14
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-04-14
#     Image 8:
#       Date : 2019-04-19
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-19
#     Image 9:
#       Date : 2019-04-24
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-24
# Zone : 0309
#   Nombre d'images : 4
#   Dossier : 0309
#     Image 1:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 2:
#       Date : 2019-02-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 3:
#       Date : 2019-02-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-15
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-15
# Zone : 0171
#   Nombre d'images : 5
#   Dossier : 0171
#     Image 1:
#       Date : 2019-02-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-02
#     Image 2:
#       Date : 2019-02-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-27
#     Image 3:
#       Date : 2019-03-29
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-29
#     Image 4:
#       Date : 2019-04-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-13
#     Image 5:
#       Date : 2019-04-18
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-18
# Zone : 4
#   Nombre d'images : 4
#   Dossier : 4
#     Image 1:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 2:
#       Date : 2019-02-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 3:
#       Date : 2019-02-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-15
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-15
# Zone : 54
#   Nombre d'images : 5
#   Dossier : 54
#     Image 1:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 2:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 3:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 4:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-01
#     Image 5:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
# Zone : 0272
#   Nombre d'images : 9
#   Dossier : 0272
#     Image 1:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 2:
#       Date : 2019-03-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-02
#     Image 3:
#       Date : 2019-03-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-04
#     Image 4:
#       Date : 2019-03-07
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-07
#     Image 5:
#       Date : 2019-03-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-09
#     Image 6:
#       Date : 2019-03-12
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 7:
#       Date : 2019-03-17
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-17
#     Image 8:
#       Date : 2019-03-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-19
#     Image 9:
#       Date : 2019-03-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-22
# Zone : 0137
#   Nombre d'images : 6
#   Dossier : 0137
#     Image 1:
#       Date : 2019-02-23
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02

#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 2:
#       Date : 2019-02-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-13
#     Image 3:
#       Date : 2019-02-28
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-28
#     Image 4:
#       Date : 2019-03-15
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-15
# Zone : 0015
#   Nombre d'images : 9
#   Dossier : 0015
#     Image 1:
#       Date : 2018-12-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-25
#     Image 2:
#       Date : 2018-12-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-30
#     Image 3:
#       Date : 2019-01-09
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-09
#     Image 4:
#       Date : 2019-01-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-14
#     Image 5:
#       Date : 2019-01-19
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-19
#     Image 6:
#       Date : 2019-01-24
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-24
#     Image 7:
#       Date : 2019-01-29
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-29
#     Image 8:
#       Date : 2019-02-03
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-03
#     Image 9:
#       Date : 2019-02-08
#       Inondation : False
#       Couverture complète : False
#       Nom de fichier : S2_2019-02-08
# Zone : 0076
#   Nombre d'images : 7
#   Dossier : 0076
#     Image 1:
#       Date : 2018-12-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-26
#     Image 2:
#       Date : 2018-12-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-31
#     Image 3:
#       Date : 2019-01-05
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-05
#     Image 4:
#       Date : 2019-01-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-10
#     Image 5:
#       Date : 2019-01-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-30
#     Image 6:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
#     Image 7:
#       Date : 2019-02-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-14
# Zone : 0102
#   Nombre d'images : 7
#   Dossier : 0102
#     Image 1:
#       Date : 2018-12-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-13
#     Image 2:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 3:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-02
#     Image 4:
#       Date : 2019-01-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-22
#     Image 5:
#       Date : 2019-01-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-27
#     Image 6:
#       Date : 2019-02-06
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-06
#     Image 7:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
# Zone : 0096
#   Nombre d'images : 7
#   Dossier : 0096
#     Image 1:
#       Date : 2018-12-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-13
#     Image 2:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 3:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-02
#     Image 4:
#       Date : 2019-01-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-22
#     Image 5:
#       Date : 2019-01-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-27
#     Image 6:
#       Date : 2019-02-06
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-06
#     Image 7:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
# Zone : 0174
#   Nombre d'images : 5
#   Dossier : 0174
#     Image 1:
#       Date : 2019-02-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-02
#     Image 2:
#       Date : 2019-02-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-27
#     Image 3:
#       Date : 2019-03-29
#       Inondation : True
#       Couverture complète : False
#       Nom de fichier : S2_2019-03-29
#     Image 4:
#       Date : 2019-04-13
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-13
#     Image 5:
#       Date : 2019-04-18
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-18
# Zone : 0149
#   Nombre d'images : 9
#   Dossier : 0149
#     Image 1:
#       Date : 2019-01-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-26
#     Image 2:
#       Date : 2019-01-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-31
#     Image 3:
#       Date : 2019-02-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-10
#     Image 4:
#       Date : 2019-02-25
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-25
#     Image 5:
#       Date : 2019-03-12
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-03-12
#     Image 6:
#       Date : 2019-04-01
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-01
#     Image 7:
#       Date : 2019-04-06
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-06
#     Image 8:
#       Date : 2019-04-16
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-16
#     Image 9:
#       Date : 2019-04-21
#       Inondation : True
#       Couverture complète : True
#       Nom de fichier : S2_2019-04-21
# Zone : 0091
#   Nombre d'images : 7
#   Dossier : 0091
#     Image 1:
#       Date : 2018-12-13
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-13
#     Image 2:
#       Date : 2018-12-28
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-28
#     Image 3:
#       Date : 2019-01-02
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-02
#     Image 4:
#       Date : 2019-01-22
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-22
#     Image 5:
#       Date : 2019-01-27
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-27
#     Image 6:
#       Date : 2019-02-06
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-06
#     Image 7:
#       Date : 2019-02-11
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-11
# Zone : 0080
#   Nombre d'images : 7
#   Dossier : 0080
#     Image 1:
#       Date : 2018-12-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-26
#     Image 2:
#       Date : 2018-12-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-31
#     Image 3:
#       Date : 2019-01-05
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-05
#     Image 4:
#       Date : 2019-01-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-10
#     Image 5:
#       Date : 2019-01-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-30
#     Image 6:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
#     Image 7:
#       Date : 2019-02-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-14
# Zone : 29
#   Nombre d'images : 7
#   Dossier : 29
#     Image 1:
#       Date : 2018-12-26
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-26
#     Image 2:
#       Date : 2018-12-31
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2018-12-31
#     Image 3:
#       Date : 2019-01-05
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-05
#     Image 4:
#       Date : 2019-01-10
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-10
#     Image 5:
#       Date : 2019-01-30
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-01-30
#     Image 6:
#       Date : 2019-02-04
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-04
#     Image 7:
#       Date : 2019-02-14
#       Inondation : False
#       Couverture complète : True
#       Nom de fichier : S2_2019-02-14

# %% [markdown]
# # Make a dataset of paths and labels

# %% [markdown]
# # Helper Functions

# %%
def load_json(path):
    '''loads a json file'''
    with open(path,'r') as file:
        js = json.load(file)
        
    return js

# collectionss1 = load_json('../input/sen12flood/sen12flood/sen12floods_s1_source/sen12floods_s1_source/collection.json')
# collections2= load_json('../input/sen12flood/sen12flood/sen12floods_s2_source/sen12floods_s2_source/collection.json')
# collections2

# %%
def process_label_json(label_json):
    '''process a single label json'''
    info_dict = {}
    
    info_dict['geometry'] = label_json['geometry']['coordinates']
    info_dict['label'] = label_json['properties']['FLOODING']
    info_dict['date'] = label_json['properties']['date']
    info_dict['tile_number'] = label_json['properties']['tile']
#     info_dict['full_data_coverage']= label_json['properties']['FULL-DATA-COVERAGE']
    
    return info_dict


def process_label_stac(stac_json):
    return stac_json['id']
    
    


def image_path_from_label_dir(image_parent_dir:str,
                              label_file :str)->str:
    
    return image_parent_dir + '/' + label_file.replace('labels','source')
    
    

def process_json(label_path,image_directory):
    '''get the data for a single example
     Inputs 
     label_path : path to the label folder 
     image_directory: path to the corresponding image directory'''
    
    

    #get image directory for that label
    folder_id = label_path.rsplit('/',1)[1]
    image_dir_path = image_path_from_label_dir(image_directory,folder_id)

    if not os.path.exists(image_dir_path):
        return {'File_not_found':image_dir_path}
    
    
    for file in os.listdir(label_path):
        #if image dir exists 
        if file.startswith('labels'):
            label_json = load_json(os.path.join(label_path,file))
        else:
            stac_json = load_json(os.path.join(label_path,file))


    #get data 
    info_dict = process_label_json(label_json)

    #get id 
    info_dict['id'] = process_label_stac(stac_json)
    
    #location id 
    info_dict['location_id'] = info_dict['id'].split('_')[3]
    
    
    info_dict['image_dir'] = image_dir_path
    
    
    return info_dict

# %%
def get_dataframe(label_directory,image_directory):
    '''get dataframe from the nested label directory'''
    records = []
    
        
    for folder in os.listdir(label_directory):
        if folder.startswith('sen12'):
#             print(folder,label_directory)
            folder_path = label_directory + '/' + folder
                
            
            #get data for a single example
            feature = process_json(label_path=folder_path,
                                   image_directory=image_directory)
            
            
            records.append(feature)
            
            
    return pd.DataFrame.from_records(data = records)



def type_cast_dataset(dataset):
    '''typecasting columns in dataset'''
    dataset['label'] = dataset['label'].astype(int)
    
    dataset['date'] = pd.to_datetime(dataset['date'])
    dataset['tile_number'] = dataset['tile_number'].astype('int8')
    
    
    return dataset

# %%
# s1_data = type_cast_dataset(
#                             get_dataframe(
#                                 label_directory=s1_labels,
#                                 image_directory=s1_tiles
#                                         )
#                             )


# s2_data = type_cast_dataset(
#                             get_dataframe(label_directory=s2_labels,
#                                           image_directory=s2_tiles)
#                             )

# print(f'Number of unique locations in Sentinel1 (SAR) data : {s1_data.location_id.nunique()}')
# print(f'Number of unique locations in Sentinel2 (optical) data : {s2_data.location_id.nunique()}')

# s1_data.shape,s2_data.shape

# %%
# saving datasets
s1_data = pd.read_csv('sen12flood/s1_data.csv')
s2_data = pd.read_csv('sen12flood/s2_data.csv')

s1_data.shape
s2_data.shape
# Out:
# (2236, 7)

# %% [markdown]
# # Attributs du Dataframe

# %%
def load_raster(filepath):
    '''load a single band raster'''
    with rio.open(filepath) as file: 
        raster = file.read().squeeze(axis=0)
        
    return raster

# %% [markdown]
# **Loading multiple raster bands as single raster**

# %%
def load_s1_tiffs(folder,
                  scaling_values=[50.,100.]):
    images = []
    i = 0
    for im in sorted(os.listdir(folder)):
         
        if im.rsplit('.',maxsplit=1)[1] == 'tif':
            
            path = folder + '/' + im
            band = load_raster(path)
            band = band / scaling_values[i]
            
            band = cv2.resize(band,
                              CFG.img_size)
            
            images.append(band)
            i+=1 
                    
    return np.dstack(images)


def load_s2_tiffs(folder,
                  scaling_value=10000.):
    images = []
    for im in sorted(os.listdir(folder)):
        if im.rsplit('.',maxsplit=1)[1] == 'tif':    
            path = folder + '/' + im
            band = load_raster(path)
            band = band/ scaling_value
            
            band = cv2.resize(band,CFG.img_size)
            images.append(band)   

    return np.dstack(images)
                    
def load_rgb_tiffs(folder,
                  scaling_value=10000.):
    '''load R,G and B bands'''
    
    images = []
    for im in sorted(os.listdir(folder)):
        name,file_format = im.rsplit('.',maxsplit=1)
        if ((file_format== 'tif') and (name in ['B02','B03','B04'])):    
            path = folder + '/' + im
            band = load_raster(path)
            band = band/ scaling_value
            
            band = cv2.resize(band,CFG.img_size)
            images.append(band)   

    return np.dstack(images)[:,:,::-1]


    
def tf_load_s1(path):    
    path = path.numpy().decode('utf-8')
    return load_s1_tiffs(path)
    
    

def tf_load_s2(path):    
    path = path.numpy().decode('utf-8')
    return load_s2_tiffs(path)


def tf_load_rgb(path):    
    path = path.numpy().decode('utf-8')
    return load_rgb_tiffs(path)
    
def process_image_s1(filename):
    '''function for preprocessing in tensorflow data'''
    
    return tf.py_function(tf_load_s1, 
                          [filename], 
                          tf.float32)



def process_image_s2(filename):
    '''function for preprocessing in tensorflow data'''
    
    return tf.py_function(tf_load_s2, 
                          [filename], 
                          tf.float32)



def process_image_rgb(filename):
    '''function for preprocessing in tensorflow data'''
    
    return tf.py_function(tf_load_rgb, 
                          [filename], 
                          tf.float32)

# %%
def count_rasters_in_folder(path):
    count = 0 
    
    for file in os.listdir(path):
        if file.rsplit('.',1)[1] == 'tif':
            count +=1 
            
    return count 
    
    
s2_data['raster_count'] = s2_data.image_dir.apply(lambda x : count_rasters_in_folder(x))

#value counts 
s2_data['raster_count'].value_counts()


s2_data=s2_data[s2_data['raster_count']==12] # take only valid rasters
# s2_data[s2_data['raster_count']==0]['location_id'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 11
#       6             count +=1
#       8     return count
# ---> 11 s2_data['raster_count'] = s2_data.image_dir.apply(lambda x : count_rasters_in_folder(x))
#      13 #value counts
#      14 s2_data['raster_count'].value_counts()
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[9], line 11, in <lambda>(x)
#       6             count +=1
#       8     return count
# ---> 11 s2_data['raster_count'] = s2_data.image_dir.apply(lambda x : count_rasters_in_folder(x))
#      13 #value counts
#      14 s2_data['raster_count'].value_counts()
#
# Cell In[9], line 4, in count_rasters_in_folder(path)
#       1 def count_rasters_in_folder(path):
#       2     count = 0
# ----> 4     for file in os.listdir(path):
#       5         if file.rsplit('.',1)[1] == 'tif':
#       6             count +=1
#
# FileNotFoundError: [WinError 3] Le chemin d’accès spécifié est introuvable: '../input/sen12flood/sen12flood/sen12floods_s2_source/sen12floods_s2_source//sen12floods_s2_source_0244_2019_04_23'

# %%
import re
def extract_number_from_path(path):
    match = re.search(r'source_(\d+)', path)
    if match:
        return match.group(1)
    else:
        return None
    

nombre = extract_number_from_path("../input/sen12flood/sen12flood/sen12floods_s1_source/sen12floods_s1_source//sen12floods_s1_source_0025_2018_12_25")
nombre
s1_data['chemin_directory'] = s1_data['image_dir'].apply(extract_number_from_path)
s1_data[["date_satellites_S1", "location_id", "label", "chemin_directory"]][s1_data["chemin_directory"] == "0001"].head()
s1_data['chemin_directory']=s1_data['chemin_directory'].astype(str)
s1_data.head()
# Out:
#   location_id  image_number       date  label       orbit  \
# 0        0063             1 2019-01-28      0   ASCENDING
# 1        0063             2 2019-02-09      0   ASCENDING
# 2        0200             1 2019-02-23      0  DESCENDING
# 3        0200             2 2019-02-28      0   ASCENDING
# 4        0200             3 2019-03-07      0  DESCENDING
#
#                                             filename folder  \
# 0  S1B_IW_GRDH_1SDV_20190128T163241_20190128T1633...   0063
# 1  S1B_IW_GRDH_1SDV_20190209T163240_20190209T1633...   0063
# 2  S1A_IW_GRDH_1SDV_20190223T031705_20190223T0317...   0200
# 3  S1B_IW_GRDH_1SDV_20190228T162250_20190228T1623...   0200
# 4  S1A_IW_GRDH_1SDV_20190307T031705_20190307T0317...   0200
#
#                                            image_dir chemin_directory  \
# 0  sen12floods_s1_source\sen12floods_s1_source_00...             0063
# 1  sen12floods_s1_source\sen12floods_s1_source_00...             0063
# 2  sen12floods_s1_source\sen12floods_s1_source_02...             0200
# 3  sen12floods_s1_source\sen12floods_s1_source_02...             0200
# 4  sen12floods_s1_source\sen12floods_s1_source_02...             0200
#
#   date_satellites_S1                                        image_files
# 0           20190128  [sen12flood\0063\S1B_IW_GRDH_1SDV_20190128T163...
# 1           20190209  [sen12flood\0063\S1B_IW_GRDH_1SDV_20190209T163...
# 2           20190223  [sen12flood\0200\S1A_IW_GRDH_1SDV_20190223T031...
# 3           20190228  [sen12flood\0200\S1B_IW_GRDH_1SDV_20190228T162...
# 4           20190307  [sen12flood\0200\S1A_IW_GRDH_1SDV_20190307T031...

# %%
def find_files_with_date(image_dir, date_satellites_S1, base_directory='sen12flood'):
    # Extraire le numéro à partir du chemin image_dir
    number = extract_number_from_path(image_dir)
    
    if not number:
        return []
    
    # Construire le chemin complet du dossier à parcourir
    search_directory = os.path.join(base_directory, number)
    
    # Vérifier si le dossier existe
    if not os.path.exists(search_directory):
        print(f"Le dossier {search_directory} n'existe pas.")
        return []

    # Parcourir le dossier et trouver les fichiers contenant la date
    matching_files = []
    for root, dirs, files in os.walk(search_directory):
        for file in files:
            if date_satellites_S1 in file:
                matching_files.append(os.path.join(root, file))
    
    return matching_files

# Appliquer la fonction à chaque ligne du dataframe
s1_data["nouveau_chemin"] = s1_data.apply(
    lambda row: find_files_with_date(
        row["image_dir"], 
        # Convertir datetime en chaîne au format YYYYMMDD
        row["date"].strftime("%Y%m%d") if isinstance(row["date"], pd.Timestamp) else row["date"].replace("-", "")
    ), 
    axis=1
)

# %%
s1_data.to_csv('s1_satellite_refontes.csv', index=False)

# %%
new_s1_data = pd.read_csv("satellite_S1.csv",sep=",")
new_s1_data.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 new_s1_data = pd.read_csv("satellite_S1_new.csv",sep=",")
#       2 new_s1_data.shape
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\mokht\Desktop\PDS\flood_dataset\env\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'satellite_S1_new.csv'

# %% [markdown]
# # Visualize some images

# %% [markdown]
# **lets take a look at some optical RGB images**

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))

plt.subplot(1,2,1)
chk = load_s2_tiffs(s2_data.query('label==1')['image_dir'].values[11])
plt.imshow(chk[:,:,1:4][:,:,::-1])
plt.title('Flooding')
plt.axis('off')


chk = load_s2_tiffs(s2_data.query('label==0')['image_dir'].values[20])
plt.subplot(1,2,2)
plt.imshow(chk[:,:,1:4][:,:,::-1])
plt.title('No Flooding')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 fig,ax = plt.subplots(1,2,figsize=(16,8))
#       3 plt.subplot(1,2,1)
# ----> 4 chk = load_s2_tiffs(s2_data.query('label==1')['image_dir'].values[11])
#       5 plt.imshow(chk[:,:,1:4][:,:,::-1])
#       6 plt.title('Flooding')
#
# Cell In[10], line 25, in load_s2_tiffs(folder, scaling_value)
#      22 def load_s2_tiffs(folder,
#      23                   scaling_value=10000.):
#      24     images = []
# ---> 25     for im in sorted(os.listdir(folder)):
#      26         if im.rsplit('.',maxsplit=1)[1] == 'tif':
#      27             path = folder + '/' + im
#
# FileNotFoundError: [WinError 3] Le chemin d’accès spécifié est introuvable: '../input/sen12flood/sen12flood/sen12floods_s2_source/sen12floods_s2_source//sen12floods_s2_source_15_2019_04_14'

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))

plt.subplot(1,2,1)
chk = load_s2_tiffs(s2_data.query('label==1')['image_dir'].values[101])
plt.imshow(chk[:,:,1:4][:,:,::-1])
plt.title('Flooding')
plt.axis('off')


chk = load_s2_tiffs(s2_data.query('label==0')['image_dir'].values[11])
plt.subplot(1,2,2)
plt.imshow(chk[:,:,1:4][:,:,::-1])
plt.title('No Flooding')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 4
#       1 fig,ax = plt.subplots(1,2,figsize=(16,8))
#       3 plt.subplot(1,2,1)
# ----> 4 chk = load_s2_tiffs(s2_data.query('label==1')['image_dir'].values[101])
#       5 plt.imshow(chk[:,:,1:4][:,:,::-1])
#       6 plt.title('Flooding')
#
# Cell In[10], line 25, in load_s2_tiffs(folder, scaling_value)
#      22 def load_s2_tiffs(folder,
#      23                   scaling_value=10000.):
#      24     images = []
# ---> 25     for im in sorted(os.listdir(folder)):
#      26         if im.rsplit('.',maxsplit=1)[1] == 'tif':
#      27             path = folder + '/' + im
#
# FileNotFoundError: [WinError 3] Le chemin d’accès spécifié est introuvable: '../input/sen12flood/sen12flood/sen12floods_s2_source/sen12floods_s2_source//sen12floods_s2_source_0214_2019_04_14'

# %%
# Formater le chemin et prendre la première image dans la liste de nouveau_chemin
def format_path(path_list):
    # Enlever les crochets et les guillemets
    path = path_list.strip("[]").replace("'", "").split(",")[0].strip()
    # Remplacer les doubles backslashes par des simples
    formatted_path = path.replace("\\\\", "\\")
    return formatted_path

# Exemple d'utilisation
chemin = "['sen12flood\\\\0305\\\\S1A_IW_GRDH_1SDV_20190211T194432_20190211T194457_025886_02E1B7_4856_corrected_VH.tif', 'sen12flood\\\\0305\\\\S1A_IW_GRDH_1SDV_20190211T194432_20190211T194457_025886_02E1B7_4856_corrected_VV.tif']"
formatted_chemin = format_path(chemin)
print(formatted_chemin)
# Out:
# sen12flood\0305\S1A_IW_GRDH_1SDV_20190211T194432_20190211T194457_025886_02E1B7_4856_corrected_VH.tif

# %% [markdown]
# **Some SAR images**

# %%
def load_s1_tiffs_changed(file_path, scaling_values=[50., 100.]):
    images = []
    i = 0
    # Charger le fichier TIFF individuel
    band = load_raster(file_path)
    band = band / scaling_values[i]
    band = cv2.resize(band, CFG.img_size)
    images.append(band)
    return np.dstack(images)

# %%
format_path(new_s1_data.query('label==1')['nouveau_chemin'].values[0])
# Out:
# 'sen12flood\\0305\\S1A_IW_GRDH_1SDV_20190211T194432_20190211T194457_025886_02E1B7_4856_corrected_VH.tif'

# %%
import os
import re
import json
import pandas as pd
import numpy as np
from datetime import datetime

def create_s1_dataframe(json_path, base_directory=None):
    """
    Crée un dataframe pandas à partir des métadonnées Sentinel-1
    
    Args:
        json_path (str): Chemin vers le fichier JSON S1list.json
        base_directory (str, optional): Répertoire de base contenant les images
        
    Returns:
        pd.DataFrame: DataFrame contenant les métadonnées et chemins des images
    """
    
    # 1. Chargement du fichier JSON
    with open(json_path, 'r') as f:
        s1_metadata = json.load(f)
    
    # 2. Préparation des données pour le dataframe
    records = []
    
    for area_id, area_data in s1_metadata.items():
        count = area_data.get('count', 0)
        folder = area_data.get('folder', '')
        
        for i in range(1, count + 1):
            if str(i) in area_data:
                entry = area_data[str(i)]
                
                # Création d'un enregistrement
                record = {
                    'location_id': area_id,
                    'image_number': i,
                    'date': entry.get('date', ''),
                    'label': 1 if entry.get('FLOODING', False) else 0,
                    'orbit': entry.get('orbit', ''),
                    'filename': entry.get('filename', ''),
                    'folder': folder
                }
                
                # Construction du chemin de l'image
                if base_directory:
                    # Préserver le format avec zéros (ex: "0063")
                    directory_id = area_id.zfill(4) if area_id.isdigit() else area_id
                    
                    # Formatage de la date pour le chemin
                    date_str = record['date'].replace('-', '')
                    
                    # Construction du chemin complet
                    image_dir = os.path.join(
                        base_directory, 
                        f"sen12floods_s1_source_{directory_id}_{date_str}"
                    )
                    record['image_dir'] = image_dir
                    
                    # Extraire l'ID du répertoire
                    record['chemin_directory'] = directory_id
                    record['date_satellites_S1'] = date_str
                
                records.append(record)
    
    # 3. Création du dataframe
    s1_data = pd.DataFrame(records)
    
    # 4. Conversion des types de données
    if not s1_data.empty:
        # Conversion des dates en datetime
        s1_data['date'] = pd.to_datetime(s1_data['date'])
        
        # S'assurer que chemin_directory est bien une chaîne (pour préserver les zéros)
        s1_data['chemin_directory'] = s1_data['chemin_directory'].astype(str)
    
    return s1_data

def find_image_files(s1_data, base_path="sen12flood"):
    """
    Trouve les fichiers d'images correspondant à chaque entrée du dataframe
    
    Args:
        s1_data (pd.DataFrame): DataFrame contenant les métadonnées
        base_path (str): Chemin de base pour la recherche des images
        
    Returns:
        pd.DataFrame: DataFrame mis à jour avec les chemins des fichiers
    """
    result = s1_data.copy()
    
    def find_files(row):
        directory = row['chemin_directory']
        date = row['date_satellites_S1']
        
        # Construire le chemin du répertoire
        directory_path = os.path.join(base_path, directory)
        
        if not os.path.exists(directory_path):
            return []
        
        # Rechercher les fichiers .tif qui contiennent la date
        matching_files = []
        for file in os.listdir(directory_path):
            if file.endswith('.tif') and date in file:
                matching_files.append(os.path.join(directory_path, file))
                
        return matching_files
    
    # Appliquer la fonction à chaque ligne
    result['image_files'] = result.apply(find_files, axis=1)
    
    # Filtrer pour ne garder que les entrées avec des fichiers correspondants
    result = result[result['image_files'].apply(len) > 0]
    
    return result

# %%
# Chemin vers le fichier JSON
json_path = "SEN12FLOOD/S1list.json"

# Chemin de base vers les images (ajustez selon votre structure de dossiers)
base_directory = "sen12floods_s1_source"

# Création du dataframe
s1_data = create_s1_dataframe(json_path, base_directory)

# Ajout des chemins vers les fichiers d'images
s1_data = find_image_files(s1_data)

# Sauvegarde du dataframe
s1_data.to_csv("satellites_S1_refonte.csv", index=False)

print(f"DataFrame créé avec {len(s1_data)} entrées.")
print(s1_data.head())
# Out:
# DataFrame créé avec 3195 entrées.
#   location_id  image_number       date  label       orbit  \
# 0        0063             1 2019-01-28      0   ASCENDING
# 1        0063             2 2019-02-09      0   ASCENDING
# 2        0200             1 2019-02-23      0  DESCENDING
# 3        0200             2 2019-02-28      0   ASCENDING
# 4        0200             3 2019-03-07      0  DESCENDING
#
#                                             filename folder  \
# 0  S1B_IW_GRDH_1SDV_20190128T163241_20190128T1633...   0063
# 1  S1B_IW_GRDH_1SDV_20190209T163240_20190209T1633...   0063
# 2  S1A_IW_GRDH_1SDV_20190223T031705_20190223T0317...   0200
# 3  S1B_IW_GRDH_1SDV_20190228T162250_20190228T1623...   0200
# 4  S1A_IW_GRDH_1SDV_20190307T031705_20190307T0317...   0200
#
#                                            image_dir chemin_directory  \
# 0  sen12floods_s1_source\sen12floods_s1_source_00...             0063
# 1  sen12floods_s1_source\sen12floods_s1_source_00...             0063
# 2  sen12floods_s1_source\sen12floods_s1_source_02...             0200
# 3  sen12floods_s1_source\sen12floods_s1_source_02...             0200
# 4  sen12floods_s1_source\sen12floods_s1_source_02...             0200
#
#   date_satellites_S1                                        image_files
# 0           20190128  [sen12flood\0063\S1B_IW_GRDH_1SDV_20190128T163...
# 1           20190209  [sen12flood\0063\S1B_IW_GRDH_1SDV_20190209T163...
# 2           20190223  [sen12flood\0200\S1A_IW_GRDH_1SDV_20190223T031...
# 3           20190228  [sen12flood\0200\S1B_IW_GRDH_1SDV_20190228T162...
# 4           20190307  [sen12flood\0200\S1A_IW_GRDH_1SDV_20190307T031...

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
plt.suptitle('SAR images (VV)')


r_idx = np.random.randint(low=0,high=500)
plt.subplot(1,2,1)
chk = load_s1_tiffs_changed(format_path(new_s1_data.query('label==1')['nouveau_chemin'].values[50]))
plt.imshow(chk[:,:,0])
plt.title('Flooding')
plt.axis('off')
plt.tight_layout()

chk = load_s1_tiffs_changed(format_path(new_s1_data.query('label==0')['nouveau_chemin'].values[50]))
plt.subplot(1,2,2)
plt.imshow(chk[:,:,0])
plt.title('No Flooding')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))
plt.suptitle('SAR images (VV)')


r_idx = np.random.randint(low=0,high=500)
plt.subplot(1,2,1)
chk = load_s1_tiffs(s1_data.query('label==1')['image_dir'].values[r_idx])
plt.imshow(chk[:,:,0])
plt.title('Flooding')
plt.axis('off')


chk = load_s2_tiffs(s2_data.query('label==0')['image_dir'].values[r_idx])
plt.subplot(1,2,2)
plt.imshow(chk[:,:,0])
plt.title('No Flooding')
plt.axis('off')
plt.tight_layout()

plt.show()

# %% [markdown]
# **Lets look at the distribution of target values**

# %%
fig,ax = plt.subplots(1,2,figsize=(16,8))

plt.subplot(1,2,1)
sns.countplot(s1_data.label)
plt.title('Sentinel -1 target distribution')


plt.subplot(1,2,2)
sns.countplot(s2_data.label)
plt.title('Sentinel - 2 target distribution')
plt.show()

# %% [markdown]
# # Making a TF dataset

# %% [markdown]
#     First lets split the dataset into training and validation set. We will stratify based on location id to ensure that locations are well represented in traininng and validation set

# %%
#isolating single loaction ids (as they will be a problem for stratification)

# single example locations 
single_index = s2_data['location_id'].value_counts()[s2_data['location_id'].value_counts()==1].index

single_index_df = s2_data[s2_data['location_id'].isin(single_index)].reset_index(drop=True)
s2_data0 = s2_data[~(s2_data['location_id'].isin(single_index))].reset_index(drop=True)

s2_data0.shape,single_index_df.shape

# %% [markdown]
# **Split dataset into train and validation splits**

# %%
#traintest split 

s1_data_tr,s1_data_val= train_test_split(s1_data,
                                          test_size = CFG.validation_size,
                                          random_state = CFG.seed,
                                          stratify = s1_data.location_id)



s2_data_tr,s2_data_val = train_test_split(s2_data0,
                                          test_size = CFG.validation_size,
                                          random_state = CFG.seed,
                                          stratify =  s2_data0.location_id)

s2_data_tr = s2_data_tr.append(single_index_df,ignore_index=True)

del s2_data0;gc.collect()

# %%
s1_data_tr.label.value_counts(1),s1_data_val.label.value_counts(1)

# %%
s2_data_tr.label.value_counts(1),s2_data_val.label.value_counts(1)

# %% [markdown]
# **Function for image augmentations**
#
#     Although the Augmentations are simple, we cannot use them on SAR images , as even simple operations like flipping can change the meaning of the image

# %%
def augment_image_multispectral(image):
    '''perform simple image augmentations'''
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_crop(image, size=(*CFG.img_size,12))
    
    rot = tf.random.normal((1,),mean = 0.35, stddev=0.15)
    
    if rot > 0.5:
        image = tf.image.rot90(image)

    return image 

def augment_image(image):
    '''perform simple image augmentations'''
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_crop(image, size=(*CFG.img_size,3))
    
    rot = tf.random.normal((1,),mean = 0.35, stddev=0.15)
    
    if rot > 0.5:
        image = tf.image.rot90(image)

    return image

# %%
def get_tf_dataset(image_paths,
                   labels=None, # put none for test data set
                   image_processing_fn=None,
                   augment_fn = None
                  ):
    
    '''returns a tf dataset object
    Inputs: 
    image_paths : paths to images
    labels: labels of each image
    image_processing_fn:  function to load and preprocess images 
    augment_fn : function to augment images '''
    
    #seperate datasets
    if labels is not None:
        labels_dataset = tf.data.Dataset.from_tensor_slices(labels)
    
    
    
    image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
    #load images 
    image_dataset = image_dataset.map(image_processing_fn,
                                      num_parallel_calls=tf.data.AUTOTUNE)
     
    if augment_fn is not None:
        
        image_dataset = image_dataset.map(augment_fn,
                                          num_parallel_calls=tf.data.AUTOTUNE)
     
    
    if labels is not None:
        return tf.data.Dataset.zip((image_dataset,labels_dataset))
    
    
    return image_dataset



def optimize_pipeline(tf_dataset,
                      batch_size = CFG.BATCH_SIZE,
                      Autotune_fn = CFG.Autotune,
                      cache= False,
                      batch = True):
    
    
    
    # prefetch(load the data with cpu,while gpu is training) the data in memory 
    tf_dataset = tf_dataset.prefetch(buffer_size=Autotune_fn)  
    if cache:
        tf_dataset = tf_dataset.cache()                        # store data in RAM  
        
    tf_dataset =  tf_dataset.shuffle(buffer_size=50)         # shuffle 
    
    if batch:
        tf_dataset = tf_dataset.batch(batch_size)              #split the data in batches  
    
    return tf_dataset

# %% [markdown]
# **Making dataset pipelines with TF data**

# %%
# Sentinel 1 dataset (not using augmentation here)

S1_dataset_tr = optimize_pipeline(tf_dataset=get_tf_dataset(image_paths = s1_data_tr.image_dir.values,
                                               labels = s1_data_tr.label,
                                               image_processing_fn = process_image_s1),
                                  
                                  batch_size = 3 * CFG.BATCH_SIZE)


S1_dataset_val = optimize_pipeline(tf_dataset = get_tf_dataset(image_paths = s1_data_val.image_dir.values,
                                                           labels = s1_data_val.label,
                                                           image_processing_fn = process_image_s1 ),
                                   batch_size = 3* CFG.BATCH_SIZE
                                  )

# %%
#sentinel 2 dataset 
S2_dataset_tr = optimize_pipeline(get_tf_dataset(image_paths = s2_data_tr.image_dir.values,
                                                   labels = s2_data_tr.label,
                                                   image_processing_fn = process_image_s2,
                                                   augment_fn = augment_image_multispectral)
                                 )


S2_dataset_val = optimize_pipeline(get_tf_dataset(image_paths = s2_data_val.image_dir.values,
                                                   labels = s2_data_val.label,
                                                   image_processing_fn = process_image_s2,
                                                   augment_fn = augment_image_multispectral)
                                  )

# %%
RGB_dataset_tr = optimize_pipeline(get_tf_dataset(image_paths = s2_data_tr.image_dir.values,
                                                   labels = s2_data_tr.label,
                                                   image_processing_fn = process_image_rgb,
                                                   augment_fn = augment_image),
                                   batch_size = 3* CFG.BATCH_SIZE
                                 )


RGB_dataset_val = optimize_pipeline(get_tf_dataset(image_paths = s2_data_val.image_dir.values,
                                                   labels = s2_data_val.label,
                                                   image_processing_fn = process_image_rgb,
                                                   augment_fn = augment_image),
                                    batch_size = 3* CFG.BATCH_SIZE
                                  )

# %% [markdown]
# **Checking the values of pixels in the dataset**

# %%
# max_vals_vv = []
# mean_vals_vv =[]


# max_vals_vh = []
# mean_vals_vh =[]

# for x,y in S1_dataset_tr.as_numpy_iterator():
#     # vv band 
#     max_vals_vv.append(x[:,:,:,0].max()); mean_vals_vv.append(x[:,:,:,0].mean())
    
#     # vh band 
#     max_vals_vh.append(x[:,:,:,1].max()); mean_vals_vh.append(x[:,:,:,1].mean())
    
# # band 1value distributions 
# plt.figure(figsize=(16,10))

# sns.distplot(max_vals_vv,label = 'VV band Max values',color='b')
# # sns.distplot(mean_vals_vv,label = 'VV band Mean values',color = 'g')

# plt.legend()

# plt.title('VV band values Distribution')
# plt.show()

# # band 1value distributions 
# plt.figure(figsize=(16,10))

# sns.distplot(max_vals_vh,label = 'VH band Max values',color='b')
# # sns.distplot(mean_vals_vh,label = 'VH band Mean values',color = 'g')


# plt.title('VH band values Distribution')

# plt.legend()
# plt.show()

# %% [markdown]
# **Checking to see if the Pipelines work as expected**

# %%
for x,y in S1_dataset_tr.take(1): # take one batch for checking 
    print(f'shape of SAR dataset input {x.shape}')

# %%
for x,y in S2_dataset_tr.take(1): # take one batch for checking 
    print(f'shape of MultiSpectral dataset input {x.shape}')

# %%
for x,y in RGB_dataset_tr.take(1): # take one batch for checking 
    print(f'shape of MultiSpectral dataset input {x.shape}')

# %% [markdown]
# #  CNN Models
#     CNN models to identify flooding in opotical and SAR images

# %%
def multichannel_cnn(num_channels:int,
                     hidden_units:int, #number of  hidden dense 
                     weights = None  # none for random init, use imagenet for imagenet weights 
                    ):
    '''model that takes multiple channel as input, instead of using the rgb channels as by default'''
    
    
    backbone = tf.keras.applications.resnet_v2.ResNet50V2(
                                            include_top=False,
                                            input_shape = (*CFG.img_size,num_channels),
                                            weights=weights,
                                            pooling = 'avg')
    
    
    x = tf.keras.layers.BatchNormalization()(backbone.output)
    x = tf.keras.layers.Dense(hidden_units,
                              activation = 'relu')(x)
    
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(rate = 0.2)(x)

    
    
    
    final_out = tf.keras.layers.Dense(2,
                                      activation = 'softmax')(x)
    
    
    #make a model 
    model = tf.keras.Model(inputs = backbone.input, 
                  outputs = final_out)
    
    return model 


# plot train and val acc as  a function of epochs
def plot_history(history,addn_metric=None):
    '''
    Inputs
    history:history object from tensorflow
    add_metric: metric name in the history (like f1_score)'''
    his=pd.DataFrame(history.history)
    
    if addn_metric:
        plt.subplots(1,3,figsize=(20,6))
        
        #loss:
        ax1=plt.subplot(1,3,1)
        ax1.plot(range(len(his)),his['loss'],color='g',label='training')
        ax1.plot(range(len(his)),his['val_loss'],color='r',label='validation')
        ax1.set_xlabel('EPOCHS')
        ax1.set_ylabel('LOSS')
        ax1.legend()
        ax1.set_title('Loss Per Epoch')

        #accuracy
        ax2=plt.subplot(1,3,2)
        ax2.plot(range(len(his)),his['accuracy'],color='g',label='training_acc')
        ax2.plot(range(len(his)),his['val_accuracy'],color='r',label='validation_acc')
        ax2.set_xlabel('EPOCHS')
        ax2.set_ylabel('Accuracy')
        ax2.legend()
        ax2.set_title('Accuracy Per Epoch')

    
        
        ax3= plt.subplot(1,3,3)
        ax3.plot(range(len(his)),his[f'{addn_metric}'],color='g',label='training')
        ax3.plot(range(len(his)),his[f'val_{addn_metric}'],color='r',label='validation')
        ax3.set_xlabel('EPOCHS')
        ax3.set_ylabel(f'{addn_metric}')
        ax3.legend()
        ax3.set_title(f'{addn_metric} Per Epoch')

        
    else:
        plt.subplots(1,2,figsize=(20,8))
        
    
    
        #loss:
        ax1=plt.subplot(1,2,1)
        ax1.plot(range(len(his)),his['loss'],color='g',label='training')
        ax1.plot(range(len(his)),his['val_loss'],color='r',label='validation')
        ax1.set_xlabel('EPOCHS')
        ax1.set_ylabel('LOSS')
        ax1.legend()
        ax1.set_title('Loss Per Epoch')

        #accuracy
        ax2=plt.subplot(1,2,2)
        ax2.plot(range(len(his)),his['accuracy'],color='g',label='training_acc')
        ax2.plot(range(len(his)),his['val_accuracy'],color='r',label='validation_acc')
        ax2.set_xlabel('EPOCHS')
        ax2.set_ylabel('Accuracy')
        ax2.legend()
        ax2.set_title('Accuracy Per Epoch')

        
    
    
    plt.show()

# %% [markdown]
# # Metrics

# %%
#from https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# # Building and training the SAR CNN

# %%
SAR_CNN = multichannel_cnn(num_channels = 2,
                           hidden_units = 512, #number of  hidden dense 
                          )



SAR_CNN.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy',f1_score,recall_m,precision_m]
               )

#check on some data 
# SAR_CNN(x)



# !mkdir CNN_models

# %% [markdown]
# # Defining callbacks

# %%
EPOCHS = 2 if CFG.test_run else 75
# callbacks 
#reduce_learning rate
reduce_lr=tf.keras.callbacks.ReduceLROnPlateau(patience=3,
                                                factor=0.75,
                                                min_delta=1e-2,
                                                monitor='val_accuracy',
                                                verbose=1,
                                                mode='max')

#early stopping 
early_stopping=tf.keras.callbacks.EarlyStopping(patience=15,
                                              min_delta=1e-3,
                                              monitor='val_accuracy',
                                              restore_best_weights=True,
                                              mode='max')


# exponential decay 

def lr_scheduler(epoch, lr):
    '''learning rate scheduler, decays expo after the tenth epoch'''

    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    

    
learning_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)


callbacks_1= [reduce_lr,early_stopping,learning_scheduler]

# %% [markdown]
# **Training on SAR data**

# %%
hist1 = SAR_CNN.fit(S1_dataset_tr,
                    validation_data = S1_dataset_val,
                    epochs = EPOCHS,
                    callbacks = callbacks_1
                   )


#save model
sar_model_path = 'CNN_models/SAR_CNN.h5'
SAR_CNN.save(filepath = 'CNN_models/SAR_CNN.h5')


#plot history 
plot_history(hist1,'f1_score')

# %% [markdown]
# ****Evaluate on validation dataset****

# %%
SAR_CNN.evaluate(S1_dataset_val)

del SAR_CNN;gc.collect()

K.clear_session()

# %% [markdown]
# # Model explainablity

# %% [markdown]
#     Saliency and Grad Cam. Lets look at what the model is looking at while making htat decision

# %%
# !pip install tf_keras_vis -q
import tf_keras_vis 

from tf_keras_vis.saliency import Saliency
from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.utils.scores import CategoricalScore
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from tf_keras_vis.gradcam_plus_plus import GradcamPlusPlus


tf_keras_vis.__version__


def model_modifier_function(cloned_model):
    '''modify model activation'''
    cloned_model.layers[-1].activation = tf.keras.activations.linear

    
def get_saliency(img,
                 score,
                 cnn_model,
                 model_modifier=model_modifier_function):
    #saliency map
    

    # Create Saliency object.
    saliency = Saliency(cnn_model,
                        model_modifier=model_modifier_function,
                        clone=True)
    #saliency map 
    sal_map  = saliency(score,
                        img,
                        smooth_samples=20, # The number of calculating gradients iterations.
                        smooth_noise=0.20) # noise spread level.
    return sal_map

def get_gradcam(img,
                score,
                cnn_model,
                model_modifier=model_modifier_function):

    # Create Gradcam object
    gradcam = Gradcam(cnn_model,
                      model_modifier,
                      clone=True)

    # Generate heatmap with GradCAM
    cam = gradcam(score,
                  img,
                  seek_penultimate_conv_layer=True)
    
    heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
    
    
    return heatmap

def get_gradcam_plus(img,
                    score,
                    model,
                    model_modifier=ReplaceToLinear()):
    
    # Create GradCAM++ object
    gradcam = GradcamPlusPlus(model,
                          model_modifier=model_modifier,
                          clone=True)
    
    cam = gradcam(score,
                  img)
    
    heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
    
    return heatmap

# %%
SAR_CNN = tf.keras.models.load_model('CNN_models/SAR_CNN.h5',
                                     custom_objects={'f1_score':f1_score,
                                                     'recall_m':recall_m,
                                                     'precision_m':precision_m}
                                    )

# %%
plt.subplots(4,4,figsize=(8*3,8*3))
n = 4
idx= 1


for images,labels in S1_dataset_val.shuffle(buffer_size=5).take(1):
    print(images.shape,labels.shape)

    for i in range(4):
        #get label 
        img = images[i]
        lab = int(labels[i].numpy())
        
        #predict on image
        pred = np.argmax(SAR_CNN.predict(img[tf.newaxis,:,:,:]))
        prd = int(pred.ravel())

        score1 = CategoricalScore(lab)

        plt.subplot(4,4,idx)
        plt.title(f'orignal image ({CFG.class_dict[lab]})')
        plt.axis('off')
        plt.imshow(img[:,:,0])
        idx+=1

        #saliency

        plt.subplot(4,4,idx)
        plt.title(f'predicted {CFG.class_dict[prd]} (saliency map)')
        sal = get_saliency(img,
                           score1,
                           cnn_model = SAR_CNN).squeeze(axis=0)
        
#         print(sal.shape)
        plt.axis('off')
        plt.imshow(img[:,:,0])
        plt.imshow(sal,alpha=0.25,cmap='jet') #overlay
        idx+=1

        #gradcam
        plt.subplot(4,4,idx)
        gdcam = get_gradcam(img,
                            score1,
                           cnn_model = SAR_CNN)
        plt.imshow(img[:,:,0])
        plt.imshow(gdcam,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam)')
        plt.axis('off')
        idx+=1


        #gradcam ++
        plt.subplot(4,4,idx)
        gdcam_pls = get_gradcam_plus(img,
                                     score1,
                                     model = SAR_CNN)
        plt.imshow(img[:,:,0])
        plt.imshow(gdcam_pls,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam + +)')
        plt.axis('off')
        idx+=1

        if idx>16:
            break

    plt.tight_layout()
    plt.show()

# %%
plt.subplots(4,4,figsize=(8*3,8*3))
n = 4
idx= 1

for images,labels in S1_dataset_val.shuffle(buffer_size=5).take(1):
    print(images.shape,labels.shape)

    for i in range(4):
        #get label 
        img = images[i]
        lab = int(labels[i].numpy())
     
        #predict on image
        pred = np.argmax(SAR_CNN.predict(img[tf.newaxis,:,:,:]))
        score1 = CategoricalScore(lab)
        prd = int(pred.ravel())

        plt.subplot(4,4,idx)
        plt.title(f'orignal image ({CFG.class_dict[lab]})')
        plt.axis('off')
        plt.imshow(img[:,:,1])
        idx+=1
        #saliency
        plt.subplot(4,4,idx)
        plt.title(f'predicted {CFG.class_dict[prd]} (saliency map)')
        sal = get_saliency(img,
                           score1,
                           cnn_model = SAR_CNN).squeeze(axis=0)
        
        plt.axis('off')
        plt.imshow(img[:,:,1])
        plt.imshow(sal,alpha=0.25,cmap='jet') #overlay
        idx+=1

        #gradcam
        plt.subplot(4,4,idx)
        gdcam = get_gradcam(img,
                            score1,
                           cnn_model = SAR_CNN)
        plt.imshow(img[:,:,1])
        plt.imshow(gdcam,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam)')
        plt.axis('off')
        idx+=1


        #gradcam ++
        plt.subplot(4,4,idx)
        gdcam_pls = get_gradcam_plus(img,
                                     score1,
                                     model = SAR_CNN)
        plt.imshow(img[:,:,1])
        plt.imshow(gdcam_pls,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam + +)')
        plt.axis('off')
        idx+=1

        if idx>16:
            break

    plt.tight_layout()
    plt.show()

# %%
#delete 
del SAR_CNN;S1_dataset_val;S1_dataset_tr;gc.collect()

K.clear_session()

# %% [markdown]
# # Building and training the RGB - CNN

# %%
RGB_CNN = multichannel_cnn(num_channels = 3,
                           hidden_units = 512, #number of  hidden dense
                           weights = 'imagenet'
                          )


RGB_CNN.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy',f1_score,recall_m,precision_m])

# %%
hist2 = RGB_CNN.fit(RGB_dataset_tr,
                    validation_data = RGB_dataset_val,
                    epochs = EPOCHS,
                    callbacks = callbacks_1)

#save model

RGB_CNN.save(filepath = 'CNN_models/RGB_CNN.h5')

plot_history(hist2,'f1_score')

# %% [markdown]
# **Checking the GradCAM and saliency Maps for RGB CNN**

# %%
plt.subplots(4,4,figsize=(8*3,8*3))
n = 4
idx= 1


for images,labels in RGB_dataset_val.shuffle(buffer_size=12).take(1):

    for i in range(4):
        #get label 
        img = images[i]
        lab = int(labels[i].numpy())


#         print(img.shape,lab.shape)
        score1 = CategoricalScore(lab)



        #predict on image
        prd= np.argmax(RGB_CNN.predict(img[tf.newaxis,:,:,:]))


        plt.subplot(4,4,idx)
        plt.title(f'orignal image ({CFG.class_dict[lab]})')
        plt.axis('off')
        plt.imshow(img)
        idx+=1

        #saliency

        plt.subplot(4,4,idx)
        plt.title(f'predicted {CFG.class_dict[prd]}(saliency map)')
        sal = get_saliency(img,
                           score1,
                           cnn_model = RGB_CNN).squeeze(axis=0)
        
#         print(sal.shape)
        plt.axis('off')
        plt.imshow(img)
        plt.imshow(sal,alpha=0.45,cmap='jet') #overlay
        idx+=1

        #gradcam
        plt.subplot(4,4,idx)
        gdcam = get_gradcam(img,
                            score1,
                           cnn_model = RGB_CNN)
        plt.imshow(img)
        plt.imshow(gdcam,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam)')
        plt.axis('off')
        idx+=1


        #gradcam ++
        plt.subplot(4,4,idx)
        gdcam_pls = get_gradcam_plus(img,
                                     score1,
                                     model = RGB_CNN)
        plt.imshow(img)
        plt.imshow(gdcam_pls,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam + +)')
        plt.axis('off')
        idx+=1

        if idx>16:
            break

    plt.tight_layout()
    plt.show()

# %%
plt.subplots(4,4,figsize=(8*3,8*3))
n = 4
idx= 1


for images,labels in RGB_dataset_val.shuffle(buffer_size=12).take(1):

    for i in range(4):
        #get label 
        img = images[i]
        lab = int(labels[i].numpy())


#         print(img.shape,lab.shape)
        score1 = CategoricalScore(lab)



        #predict on image
        prd= np.argmax(RGB_CNN.predict(img[tf.newaxis,:,:,:]))


        plt.subplot(4,4,idx)
        plt.title(f'orignal image ({CFG.class_dict[lab]})')
        plt.axis('off')
        plt.imshow(img)
        idx+=1

        #saliency

        plt.subplot(4,4,idx)
        plt.title(f'predicted {CFG.class_dict[prd]}(saliency map)')
        sal = get_saliency(img,
                           score1,
                           cnn_model = RGB_CNN).squeeze(axis=0)
        
#         print(sal.shape)
        plt.axis('off')
        plt.imshow(img)
        plt.imshow(sal,alpha=0.45,cmap='jet') #overlay
        idx+=1

        #gradcam
        plt.subplot(4,4,idx)
        gdcam = get_gradcam(img,
                            score1,
                           cnn_model = RGB_CNN)
        plt.imshow(img)
        plt.imshow(gdcam,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam)')
        plt.axis('off')
        idx+=1


        #gradcam ++
        plt.subplot(4,4,idx)
        gdcam_pls = get_gradcam_plus(img,
                                     score1,
                                     model = RGB_CNN)
        plt.imshow(img)
        plt.imshow(gdcam_pls,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam + +)')
        plt.axis('off')
        idx+=1

        if idx>16:
            break

    plt.tight_layout()
    plt.show()

# %%
#delete 
del RGB_CNN;gc.collect()

K.clear_session()

# %% [markdown]
# # Building and training the Multispectral - CNN

# %%
multispectral_CNN = multichannel_cnn(num_channels = 12,
                                    hidden_units = 512, #number of  hidden dense 
                                    )


#check on some data 
# multispectral_CNN(x)


multispectral_CNN.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001,momentum = 0.0),
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy',f1_score,recall_m,precision_m])

# %%
hist2 = multispectral_CNN.fit(S2_dataset_tr,
                    validation_data = S2_dataset_val,
                    epochs = EPOCHS,
                    callbacks = callbacks_1)

#save model

multispectral_CNN.save(filepath = 'CNN_models/S2_CNN.h5')

plot_history(hist2,'f1_score')

# %% [markdown]
# **Checking the decision mechanism for Multispectral model**

# %%
plt.subplots(4,4,figsize=(8*3,8*3))
n = 4
idx= 1


for images,labels in S2_dataset_val.shuffle(buffer_size=12).take(1):
    print(images.shape,labels.shape)

    for i in range(4):
        #get label 
        img = images[i]
        lab = int(labels[i].numpy())


#         print(img.shape,lab.shape)
        score1 = CategoricalScore(lab)



        #predict on image
        prd= np.argmax(multispectral_CNN.predict(img[tf.newaxis,:,:,:]))


        plt.subplot(4,4,idx)
        plt.title(f'orignal image ({CFG.class_dict[lab]})')
        plt.axis('off')
        plt.imshow(img[:,:,1:4][:,:,::-1])
        idx+=1

        #saliency

        plt.subplot(4,4,idx)
        plt.title(f'predicted {CFG.class_dict[prd]}(saliency map)')
        sal = get_saliency(img,
                           score1,
                           cnn_model = multispectral_CNN).squeeze(axis=0)
        
#         print(sal.shape)
        plt.axis('off')
        plt.imshow(img[:,:,1:4][:,:,::-1])
        plt.imshow(sal,alpha=0.45,cmap='jet') #overlay
        idx+=1

        #gradcam
        plt.subplot(4,4,idx)
        gdcam = get_gradcam(img,
                            score1,
                           cnn_model = multispectral_CNN)
        plt.imshow(img[:,:,1:4][:,:,::-1])
        plt.imshow(gdcam,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam)')
        plt.axis('off')
        idx+=1


        #gradcam ++
        plt.subplot(4,4,idx)
        gdcam_pls = get_gradcam_plus(img,
                                     score1,
                                     model = multispectral_CNN)
        plt.imshow(img[:,:,1:4][:,:,::-1])
        plt.imshow(gdcam_pls,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam + +)')
        plt.axis('off')
        idx+=1

        if idx>16:
            break

    plt.tight_layout()
    plt.show()

# %%
plt.subplots(4,4,figsize=(8*3,8*3))
n = 4
idx= 1


for images,labels in S2_dataset_val.shuffle(buffer_size=12).take(1):
    print(images.shape,labels.shape)

    for i in range(4):
        #get label 
        img = images[i]
        lab = int(labels[i].numpy())


#         print(img.shape,lab.shape)
        score1 = CategoricalScore(lab)



        #predict on image
        prd= np.argmax(multispectral_CNN.predict(img[tf.newaxis,:,:,:]))


        plt.subplot(4,4,idx)
        plt.title(f'orignal image ({CFG.class_dict[lab]})')
        plt.axis('off')
        plt.imshow(img[:,:,1:4][:,:,::-1])
        idx+=1

        #saliency

        plt.subplot(4,4,idx)
        plt.title(f'predicted {CFG.class_dict[prd]}(saliency map)')
        sal = get_saliency(img,
                           score1,
                           cnn_model = multispectral_CNN).squeeze(axis=0)
        
#         print(sal.shape)
        plt.axis('off')
        plt.imshow(img[:,:,1:4][:,:,::-1])
        plt.imshow(sal,alpha=0.30,cmap='jet') #overlay
        idx+=1

        #gradcam
        plt.subplot(4,4,idx)
        gdcam = get_gradcam(img,
                            score1,
                           cnn_model = multispectral_CNN)
        plt.imshow(img[:,:,1:4][:,:,::-1])
        plt.imshow(gdcam,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam)')
        plt.axis('off')
        idx+=1


        #gradcam ++
        plt.subplot(4,4,idx)
        gdcam_pls = get_gradcam_plus(img,
                                     score1,
                                     model = multispectral_CNN)
        plt.imshow(img[:,:,1:4][:,:,::-1])
        plt.imshow(gdcam_pls,alpha=0.30,cmap='jet') #overlay
        plt.title(f'predicted {CFG.class_dict[prd]}(gradcam + +)')
        plt.axis('off')
        idx+=1

        if idx>16:
            break

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Model for temporal forecasting
#
#     This notebooks covered the prediction of flooding using satellite images. But this dataset is as time series dataset, which has multiple images of locations before and during the flood. So we will try to cover the temporal aspect of predicting flooding in the next notebook. This can be especially important in some cases where there are water bodies in the image, and hence there needs to be additional signal to distinguish cases of flooding ffrom normal conditions
#
# [The temporal forecasting notebook can be found here](https://www.kaggle.com/code/virajkadam/detecting-floods-time-series-prediction)

# %% [markdown]
# # References and resources
#
# * https://www.int-arch-photogramm-remote-sens-spatial-inf-sci.net/XLIII-B2-2020/1343/2020/isprs-archives-XLIII-B2-2020-1343-2020.pdf
# * https://arxiv.org/pdf/2006.10027v1.pdf#page=2
